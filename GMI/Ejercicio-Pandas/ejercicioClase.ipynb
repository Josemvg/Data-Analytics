# %%
import pandas as pd

# %% [markdown]
# # Ejercicio 1 - carga de datos

# %%
df = pd.read_csv("datasets/casos_diagnostico_ccaa.csv")

# %% [markdown]
# # Ejercicio 2 - 5 primeras filas

# %%
df.head(5)
# Out:
#   ccaa_iso       fecha  num_casos  num_casos_prueba_pcr  \
# 0       AN  2020-01-01          0                     0
# 1       AR  2020-01-01          0                     0
# 2       AS  2020-01-01          0                     0
# 3       CB  2020-01-01          0                     0
# 4       CE  2020-01-01          1                     0
#
#    num_casos_prueba_test_ac  num_casos_prueba_ag  num_casos_prueba_elisa  \
# 0                         0                    0                       0
# 1                         0                    0                       0
# 2                         0                    0                       0
# 3                         0                    0                       0
# 4                         0                    1                       0
#
#    num_casos_prueba_desconocida
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0

# %% [markdown]
# # Ejercicio 3 - 5 primeras columnas

# %%
df.iloc[:,:5]
# Out:
#      ccaa_iso       fecha  num_casos  num_casos_prueba_pcr  \
# 0          AN  2020-01-01          0                     0
# 1          AR  2020-01-01          0                     0
# 2          AS  2020-01-01          0                     0
# 3          CB  2020-01-01          0                     0
# 4          CE  2020-01-01          1                     0
# ...       ...         ...        ...                   ...
# 7424       ML  2021-01-25          0                     0
# 7425       NC  2021-01-25          0                     0
# 7426       PV  2021-01-25          0                     0
# 7427       RI  2021-01-25          0                     0
# 7428       VC  2021-01-25        108                    84
#
#       num_casos_prueba_test_ac
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 7424                         0
# 7425                         0
# 7426                         0
# 7427                         0
# 7428                         0
#
# [7429 rows x 5 columns]

# %% [markdown]
# # Ejercicio 4 - tuplas dataframe

# %%
df.to_records(index=False)
# Out:
# rec.array([('AN', '2020-01-01',   0,  0, 0,  0, 0, 0),
#            ('AR', '2020-01-01',   0,  0, 0,  0, 0, 0),
#            ('AS', '2020-01-01',   0,  0, 0,  0, 0, 0), ...,
#            ('PV', '2021-01-25',   0,  0, 0,  0, 0, 0),
#            ('RI', '2021-01-25',   0,  0, 0,  0, 0, 0),
#            ('VC', '2021-01-25', 108, 84, 0, 24, 0, 0)],
#           dtype=[('ccaa_iso', 'O'), ('fecha', 'O'), ('num_casos', '<i8'), ('num_casos_prueba_pcr', '<i8'), ('num_casos_prueba_test_ac', '<i8'), ('num_casos_prueba_ag', '<i8'), ('num_casos_prueba_elisa', '<i8'), ('num_casos_prueba_desconocida', '<i8')])

# %% [markdown]
# # Ejercicio 5 - tablas con fecha "2021-01-25"

# %%
df[df.fecha == "2021-01-25"]
# Out:
#      ccaa_iso       fecha  num_casos  num_casos_prueba_pcr  \
# 7410       AN  2021-01-25          0                     0
# 7411       AR  2021-01-25          0                     0
# 7412       AS  2021-01-25          0                     0
# 7413       CB  2021-01-25          0                     0
# 7414       CE  2021-01-25          4                     1
# 7415       CL  2021-01-25          0                     0
# 7416       CM  2021-01-25          0                     0
# 7417       CN  2021-01-25          1                     1
# 7418       CT  2021-01-25          0                     0
# 7419       EX  2021-01-25          0                     0
# 7420       GA  2021-01-25          0                     0
# 7421       IB  2021-01-25          0                     0
# 7422       MC  2021-01-25          0                     0
# 7423       MD  2021-01-25          0                     0
# 7424       ML  2021-01-25          0                     0
# 7425       NC  2021-01-25          0                     0
# 7426       PV  2021-01-25          0                     0
# 7427       RI  2021-01-25          0                     0
# 7428       VC  2021-01-25        108                    84
#
#       num_casos_prueba_test_ac  num_casos_prueba_ag  num_casos_prueba_elisa  \
# 7410                         0                    0                       0
# 7411                         0                    0                       0
# 7412                         0                    0                       0
# 7413                         0                    0                       0
# 7414                         0                    2                       1
# 7415                         0                    0                       0
# 7416                         0                    0                       0
# 7417                         0                    0                       0
# 7418                         0                    0                       0
# 7419                         0                    0                       0
# 7420                         0                    0                       0
# 7421                         0                    0                       0
# 7422                         0                    0                       0
# 7423                         0                    0                       0
# 7424                         0                    0                       0
# 7425                         0                    0                       0
# 7426                         0                    0                       0
# 7427                         0                    0                       0
# 7428                         0                   24                       0
#
#       num_casos_prueba_desconocida
# 7410                             0
# 7411                             0
# 7412                             0
# 7413                             0
# 7414                             0
# 7415                             0
# 7416                             0
# 7417                             0
# 7418                             0
# 7419                             0
# 7420                             0
# 7421                             0
# 7422                             0
# 7423                             0
# 7424                             0
# 7425                             0
# 7426                             0
# 7427                             0
# 7428                             0

# %% [markdown]
# # Ejercicio 6 - numero de casos con fecha "2021-01-25"

# %%
df[df.fecha == "2021-01-25"].num_casos.sum()
# Out:
# 113

# %% [markdown]
# # Ejercicio 7 - numero de casos por CCAA

# %%
df.groupby("ccaa_iso").num_casos.sum()
# Out:
# ccaa_iso
# AN    368252
# AR     93985
# AS     33781
# CB     21694
# CE      3758
# CL    174047
# CM    139568
# CN     33713
# CT    473298
# EX     61175
# GA     86809
# IB     49611
# MC     90861
# MD    493480
# ML      5673
# NC     47106
# PV    128175
# RI     23899
# VC    271473
# Name: num_casos, dtype: int64

# %% [markdown]
# # Ejercicio 8 - CCAA con mayor numero de casos

# %%
df.groupby("ccaa_iso").num_casos.sum().sort_values(ascending=False)
# Out:
# ccaa_iso
# MD    493480
# CT    473298
# AN    368252
# VC    271473
# CL    174047
# CM    139568
# PV    128175
# AR     93985
# MC     90861
# GA     86809
# EX     61175
# IB     49611
# NC     47106
# AS     33781
# CN     33713
# RI     23899
# CB     21694
# ML      5673
# CE      3758
# Name: num_casos, dtype: int64

# %%
df.groupby("ccaa_iso").num_casos.sum().idxmax()
# Out:
# 'MD'

# %% [markdown]
# # Ejercicio 9 - CCAA con menor numero de casos

# %%
df.groupby("ccaa_iso").num_casos.sum().idxmin()
# Out:
# 'CE'
